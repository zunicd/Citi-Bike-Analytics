# %% [markdown]
# ## Data Source

# %% [markdown]
# [The Citi Bike Data webpage](https://www.citibikenyc.com/system-data)
#
# Jersey City trip histories files from 2018 to 2020 were downloaded (30 files).

# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
import glob

# Calculate geo distance between two geographic points with coordinates
from geopy.distance import distance

# %%
# Function to get geo distance between start station and end station

def geo_distance(row):
    coord_a = (row['start station latitude'], row['start station longitude'])
    coord_b = (row['end station latitude'], row['end station longitude'])
    return distance(coord_a, coord_b).miles

# %% [markdown]
# ## Preparing data for JC

# %%
# Initialize dataframe
df_jc = pd.DataFrame()

# Loop through all JC .csv files
for file_name in glob.glob('./Resources/JC-20*.csv'):
    # Read .csv files
    df = pd.read_csv(file_name)
    print(50*'-')
    print(f"File Name: {file_name} \nDF shape: {df.shape}")
    
    # Calculate geo distance between start and stations
    df['geodistance (miles)'] = df.apply(geo_distance, axis=1)
    # Move the new column "geo distance" to index 1
    col = df.pop('geodistance (miles)')
    df.insert(1, 'geodistance (miles)', col)
    # Calculating Geo distance is time consuming --> save df to csv file
    newft = file_name.split('\\')
    newf = f"{newft[0]}-gd/{newft[1]}"
    df.to_csv(newf, index=False)
    
    # Join iterated dataframe with previuos one
    df_jc = pd.concat([df_jc, df]).reset_index(drop=True)
    print(f"Current joined DF shape: {df_jc.shape}")
    
print(50*'=')
print(f"Final joined DF shape: {df_jc.shape}")
# Save the dataframe to csv file
file_name = f"./Data/JC-2018-2020-citibike-tripdata-gd.csv"
df_jc.to_csv(file_name, index=False)
# Out:
# --------------------------------------------------
# File Name: ./Resources\JC-201801-citibike-tripdata.csv
# DF shape: (12677, 15)
# Current joined DF shape: (12677, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201802-citibike-tripdata.csv
# DF shape: (15104, 15)
# Current joined DF shape: (27781, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201803-citibike-tripdata.csv
# DF shape: (17109, 15)
# Current joined DF shape: (44890, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201804-citibike-tripdata.csv
# DF shape: (23634, 15)
# Current joined DF shape: (68524, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201805-citibike-tripdata.csv
# DF shape: (34456, 15)
# Current joined DF shape: (102980, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201806-citibike-tripdata.csv
# DF shape: (40937, 15)
# Current joined DF shape: (143917, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201807-citibike-tripdata.csv
# DF shape: (42268, 15)
# Current joined DF shape: (186185, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201808-citibike-tripdata.csv
# DF shape: (44432, 15)
# Current joined DF shape: (230617, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201809-citibike-tripdata.csv
# DF shape: (39022, 15)
# Current joined DF shape: (269639, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201810-citibike-tripdata.csv
# DF shape: (39138, 15)
# Current joined DF shape: (308777, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201811-citibike-tripdata.csv
# DF shape: (24910, 15)
# Current joined DF shape: (333687, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201812-citibike-tripdata.csv
# DF shape: (20205, 15)
# Current joined DF shape: (353892, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201901-citibike-tripdata.csv
# DF shape: (19676, 15)
# Current joined DF shape: (373568, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201902-citibike-tripdata.csv
# DF shape: (18565, 15)
# Current joined DF shape: (392133, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201903-citibike-tripdata.csv
# DF shape: (23606, 15)
# Current joined DF shape: (415739, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201904-citibike-tripdata.csv
# DF shape: (33056, 15)
# Current joined DF shape: (448795, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201905-citibike-tripdata.csv
# DF shape: (36135, 15)
# Current joined DF shape: (484930, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201906-citibike-tripdata.csv
# DF shape: (39430, 15)
# Current joined DF shape: (524360, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201907-citibike-tripdata.csv
# DF shape: (43746, 15)
# Current joined DF shape: (568106, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201908-citibike-tripdata.csv
# DF shape: (48711, 15)
# Current joined DF shape: (616817, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201909-citibike-tripdata.csv
# DF shape: (49244, 15)
# Current joined DF shape: (666061, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201910-citibike-tripdata.csv
# DF shape: (42253, 15)
# Current joined DF shape: (708314, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201911-citibike-tripdata.csv
# DF shape: (30797, 15)
# Current joined DF shape: (739111, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-201912-citibike-tripdata.csv
# DF shape: (19728, 15)
# Current joined DF shape: (758839, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-202001-citibike-tripdata.csv
# DF shape: (26020, 15)
# Current joined DF shape: (784859, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-202002-citibike-tripdata.csv
# DF shape: (22962, 15)
# Current joined DF shape: (807821, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-202003-citibike-tripdata.csv
# DF shape: (17719, 15)
# Current joined DF shape: (825540, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-202004-citibike-tripdata.csv
# DF shape: (9268, 15)
# Current joined DF shape: (834808, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-202005-citibike-tripdata.csv
# DF shape: (25077, 15)
# Current joined DF shape: (859885, 16)
# --------------------------------------------------
# File Name: ./Resources\JC-202006-citibike-tripdata.csv
# DF shape: (36921, 15)
# Current joined DF shape: (896806, 16)
# ==================================================
# Final joined DF shape: (896806, 16)

# %%
df_jc.head()
# Out:
#    tripduration  geodistance (miles)                 starttime  \
# 0           932             0.865295  2018-01-01 02:06:17.5410
# 1           550             0.865295  2018-01-01 12:06:18.0390
# 2           510             0.865295  2018-01-01 12:06:56.9780
# 3           354             0.374889  2018-01-01 14:53:10.1860
# 4           250             0.211295  2018-01-01 17:34:30.1920
#
#                    stoptime  start station id start station name  \
# 0  2018-01-01 02:21:50.0270              3183     Exchange Place
# 1  2018-01-01 12:15:28.4430              3183     Exchange Place
# 2  2018-01-01 12:15:27.8100              3183     Exchange Place
# 3  2018-01-01 14:59:05.0960              3183     Exchange Place
# 4  2018-01-01 17:38:40.9840              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3199
# 1               40.716247               -74.033459            3199
# 2               40.716247               -74.033459            3199
# 3               40.716247               -74.033459            3267
# 4               40.716247               -74.033459            3639
#
#   end station name  end station latitude  end station longitude  bikeid  \
# 0     Newport Pkwy             40.728745             -74.032108   31929
# 1     Newport Pkwy             40.728745             -74.032108   31845
# 2     Newport Pkwy             40.728745             -74.032108   31708
# 3     Morris Canal             40.712419             -74.038526   31697
# 4       Harborside             40.719252             -74.034234   31861
#
#      usertype  birth year  gender
# 0  Subscriber        1992       1
# 1  Subscriber        1969       2
# 2  Subscriber        1946       1
# 3  Subscriber        1994       1
# 4  Subscriber        1991       1
